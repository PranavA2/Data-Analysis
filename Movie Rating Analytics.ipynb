# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\pajag\\DATA SCIENCE'

# %%
movies = pd.read_csv("C:\\Users\\pajag\\DATA SCIENCE\\P4-Movie-Ratings.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating','AudienceRatings','BudgetMillion','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillion         Year
# count    559.000000       559.000000     559.000000   559.000000
# mean      47.309481        58.744186      50.236136  2009.152057
# std       26.413091        16.826887      48.731817     1.362632
# min        0.000000         0.000000       0.000000  2007.000000
# 25%       25.000000        47.000000      20.000000  2008.000000
# 50%       46.000000        58.000000      35.000000  2009.000000
# 75%       70.000000        72.000000      65.000000  2010.000000
# max       97.000000        96.000000     300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
vmovies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Year.cat.categories
# Out:
# Int64Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillion
# count    559.000000       559.000000     559.000000
# mean      47.309481        58.744186      50.236136
# std       26.413091        16.826887      48.731817
# min        0.000000         0.000000       0.000000
# 25%       25.000000        47.000000      20.000000
# 50%       46.000000        58.000000      35.000000
# 75%       70.000000        72.000000      65.000000
# max       97.000000        96.000000     300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Jointpots

# %%
j = sns.jointplot(data=movies,x="CriticRating",y='AudienceRatings')

# %%
j = sns.jointplot(data=movies,x="CriticRating",y='AudienceRatings',kind='hex')

# %%
# Chart 1

# %%
#Histograms

# %%
sns.set_style("darkgrid")
m2 = sns.distplot(movies.AudienceRatings,bins=15)

# %%
n1 = plt.hist(movies.AudienceRatings, bins=15)

# %%
n1 = plt.hist(movies.CriticRating, bins=15)

# %%
# Stacked Histograms

# %%
plt.hist(movies.BudgetMillion)
plt.show()

# %%
movies.Genre == 'Drama'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# Name: Genre, Length: 559, dtype: bool

# %%
movies[movies.Genre == 'Drama'].BudgetMillion
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillion, Length: 101, dtype: int64

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion, bins=15)
plt.hist(movies[movies.Genre == 'Action'].BudgetMillion, bins=15)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillion, bins=15)
plt.show()

# %%
sta = [movies[movies.Genre == 'Drama'].BudgetMillion,movies[movies.Genre == 'Thriller'].BudgetMillion,movies[movies.Genre == 'Action'].BudgetMillion]

# %%
plt.hist(sta,stacked = True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = []
list2 = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillion)
    list2.append(gen)

h = plt.hist(list1,bins=30,stacked=True,rwidth=1, label=list2)
plt.legend()

# %%
# chart 4

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating',y='AudienceRatings',fit_reg=False, hue='Genre', size=7, aspect=1)

# %%
k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')

# %%
k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,cmap='Reds')

# %%
# Working with Subplots()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRatings)

# %%
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating)

# %%
f,axes = plt.subplots(1,2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRatings, ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,ax=axes[1] )

# %%
axes
# Out:
# array([<AxesSubplot:xlabel='BudgetMillion', ylabel='AudienceRatings'>,
#        <AxesSubplot:xlabel='BudgetMillion', ylabel='CriticRating'>],
#       dtype=object)

# %%
f,axes = plt.subplots(2,2, figsize=(12,6)) # two dimension
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRatings, ax=axes[0,1])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,ax=axes[1,0] )

# %%
f,axes = plt.subplots(1,2, figsize=(12,6), sharex=True, sharey=True)
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRatings, ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,ax=axes[1])
k1.set(xlim=(-30,220))
# Out:
# [(-30.0, 220.0)]

# %%
# ViolinPlots

# %%
z = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
w = sns.boxplot(data=movies, x='Genre', y='CriticRating')

# %%
z1 = sns.boxplot(data=movies[movies.Genre== 'Drama'],x='Year',y='CriticRating')

# %%
w1 = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')

# %%
# Creating a Facet Grid

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g = g.map(plt.scatter,'CriticRating','AudienceRatings')

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g= g.map(plt.hist,'BudgetMillion')

# %%
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRatings')

# %%
kws
# Out:
# {'s': 50, 'linewidth': 0.5, 'edgecolor': 'black'}

# %%
# Controlling Axes and adding Diagonals
g = sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRatings')
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="gray",ls="--")
g.add_legend()

# %%
# Chart 5

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize = (15,15))
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRatings, ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,ax=axes[0,1])
k1.set(xlim=(-30,220))
k2.set(xlim=(-30,220))
w1 = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating',ax=axes[1,0])
#k3 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
axes[1,1].hist(movies.CriticRating, bins=15)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("darkgrid", {"axes.facecolor":"black"})
f, axes = plt.subplots(2,2, figsize = (15,15))

#plot 0,0
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRatings, shade=True, shade_lowest=True ,cmap = 'inferno', ax=axes[0,0])
#k1b = sns.kdeplot(movies.BudgetMillion, movies.AudienceRatings, ax=axes[0,0])
#plot 0,1
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,shade=True, shade_lowest=True ,cmap = 'inferno',ax=axes[0,1])  
#k2b = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,ax=axes[0,1])

k1.set(xlim=(-30,220))
k2.set(xlim=(-30,220))

#plot 1,0
w1 = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating',ax=axes[1,0])

#plot 1,1
#k3 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds',ax=axes[1,1])
#plot1,1
axes[1,1].hist(movies.CriticRating, bins=15)
plt.show()

# %%
list1 = []
list2 = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillion)
    list2.append(gen)

sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
h = plt.hist(list1,bins=30,stacked=True,rwidth=1, label=list2)
plt.title("Movie Budget Distribution", fontsize=20, color="DarkBlue", fontname="Arial")
plt.ylabel("Number of Movies", fontsize=20, color="Red",fontname="Arial")
plt.xlabel("Budget",fontsize=20,color="Green",fontname="Arial")
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(prop={'size':20},fancybox=True,shadow=True,framealpha=1)
plt.show()
